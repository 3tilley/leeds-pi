# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,9)
from pathlib import Path

import pandas as pd
import numpy as np

# %%
p = Path() / "packet-sniffer" / "data_rust_nothing.txt"
p = Path() / "packet-sniffer" / "data_rust_three_768.txt"
p = Path() / "packet-sniffer" / "data_rust_one.txt"
if p.suffix == ".csv" :
    
    df = pd.read_csv(p)
    print(df)
    b = df["payload"][8]
else:
    b = p.read_text().replace("\n", "")

b
# Out:
# '...'

# %%
n = 1
#chunks = [b[i:i+n] for i in range(11000, 15000, n)]

chunks = [b[i:i+n] for i in range(0, len(b), n)]
b_c = [int(c,16) for c in chunks]
filt = [i for i in b_c if i < 250]
pd.DataFrame(b_c).plot(linestyle="None", marker=".")
pd.DataFrame(b_c).plot(marker=".")

# %%
plt.specgram(b_c, Fs=2)
plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5a6e92bb88f7> in <module>()
#       1 plt.specgram(b_c, Fs=2)
# ----> 2 plt.show(fig)
#
# NameError: name 'fig' is not defined

# %%
60 * 4
# Out:
# 240

# %%
int.from_bytes(b"f0", "little")
# Out:
# 12390

# %%
int("f",16)
# Out:
# 15
